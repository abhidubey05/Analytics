# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load datset
df=pd.read_csv('Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
print(df.head())
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# box plot
sns.boxplot(data=df, x='bedrooms', y='price', palette='Set2')
plt.title('House Price Distribution by Bedrooms')
plt.show()
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_16496\3941862431.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='bedrooms', y='price', palette='Set2')

# %%
# count plot
sns.countplot(data=df, x='furnishingstatus', palette='pastel')
plt.title('Count of Houses by Furnishing Status')
plt.show()
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_16496\51438155.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='furnishingstatus', palette='pastel')

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(df)
plt.suptitle("Pair Plot of All Numeric Features", y=1.02)
plt.show()

# %%
sns.pairplot(df, hue='furnishingstatus')
plt.suptitle("Pair Plot by Furnishing Status", y=1.02)
plt.show()

# %%
sns.lmplot(data=df, x='area', y='price', height=6, aspect=1.5)
plt.title("Linear Regression: Area vs Price")
plt.show()

# %%
sns.violinplot(data=df, x='bedrooms', y='price', palette='muted')
plt.title("Violin Plot: Price by Bedrooms")
plt.show()
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_16496\868926782.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='bedrooms', y='price', palette='muted')

# %%
sns.stripplot(data=df, x='bedrooms', y='price', jitter=True, palette='Set1')
plt.title("Price Distribution Across Bedrooms (Strip Plot)")
plt.show()
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_16496\2308542082.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='bedrooms', y='price', jitter=True, palette='Set1')

# %%
sns.swarmplot(data=df, x='furnishingstatus', y='price', palette='Set2')
plt.title("Price Distribution by Furnishing Status (Swarm Plot)")
plt.show()
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_16496\2653882779.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=df, x='furnishingstatus', y='price', palette='Set2')
# C:\Users\Abhishek\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
